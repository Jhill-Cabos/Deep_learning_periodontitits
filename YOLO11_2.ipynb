# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhill-Cabos/Deep_learning_periodontitits/blob/main/YOLO11_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# !pip -q install -U ultralytics opencv-python tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.6 MB/s eta 0:00:00

# %%
# @title
from ultralytics import YOLO
print("Ultralytics version OK. Loading a small YOLO11 model…")
model = YOLO("yolo11s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics version OK. Loading a small YOLO11 model…
# ...

# %%
# @title
from google.colab import drive
mountpoint = '/content/drive'
drive.mount(mountpoint)
# Out:
# Mounted at /content/drive

# %%
# @title
yaml_path = "/content/drive/MyDrive/Dataset/data.yaml"
save_dir = "/content/drive/MyDrive/runs/train_OCT12_VER2"

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

results = model.train(
    data="/content/drive/MyDrive/Dataset/data.yaml",
    epochs=150,
    batch=16,
    workers=2,
    device=0,
    patience=30,
    save=True,
    amp=False,
    pretrained=True,
    lr0=0.0005,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=3,
    box=7.5,
    cls=0.5,
    hsv_h=0.015,
    hsv_s=0.5,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.05,
    scale=0.5,
    fliplr=0.5,
    mosaic=0.8,
    mixup=0.0
)
# Out:
# Ultralytics 8.3.211 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
model.save("/content/drive/MyDrive/Models/OCT13_YOLO11.pt")

# %%
# !cp -r /content/drive/MyDrive/Dataset/labels_relabel /content/drive/MyDrive/Dataset/labels

# %%
# !rm -f /root/.config/Ultralytics/settings.json

# %%
metrics = model.val()
print("📊 Validation Results:", metrics)
# Out:
# Ultralytics 8.3.211 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLO11s summary (fused): 100 layers, 9,414,735 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.0 ms, read: 858.9±116.1 MB/s, size: 6034.9 KB)
# val: Scanning /content/drive/MyDrive/Dataset/labels/test.cache... 1096 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1096/1096 1.6Mit/s 0.0s
# train: /content/drive/MyDrive/Dataset/images/train/00060.jpg: 1 duplicate labels removed
# train: /content/drive/MyDrive/Dataset/images/train/00085.jpg: 1 duplicate labels removed
# train: /content/drive/MyDrive/Dataset/images/train/00484.jpg: 1 duplicate labels removed
# train: /content/drive/MyDrive/Dataset/images/val/00811.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 69/69 1.4it/s 49.2s
#                    all       1096      15338      0.936      0.942      0.971      0.817
# ...

# %%
import os
from google.colab import runtime
print("✅ Model saved. Stopping runtime to free resources...")
runtime.unassign()
# Out:
# ✅ Model saved. Stopping runtime to free resources...

# %%
from pathlib import Path

for split in ["train", "val", "test"]:
    imgs = list(Path(f"/content/drive/MyDrive/Dataset/images/{split}").glob("*.jpg"))
    lbls = list(Path(f"/content/drive/MyDrive/Dataset/labels_relabel/{split}").glob("*.txt"))
    print(f"{split}: {len(imgs)} images, {len(lbls)} labels")
# Out:
# train: 732 images, 732 labels
# val: 182 images, 182 labels
# test: 182 images, 182 labels
